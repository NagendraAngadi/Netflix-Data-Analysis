# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv(r'C:\Users\acer\Downloads\archive (2)\netflix1.csv')

# %%
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
#Data Analysis

df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
df.tail()
# Out:
#      show_id     type               title   director        country  \
# 8785   s8797  TV Show          Yunus Emre  Not Given         Turkey
# 8786   s8798  TV Show           Zak Storm  Not Given  United States
# 8787   s8801  TV Show  Zindagi Gulzar Hai  Not Given       Pakistan
# 8788   s8784  TV Show                Yoko  Not Given       Pakistan
# 8789   s8786  TV Show                 YOM  Not Given       Pakistan
#
#       date_added  release_year rating   duration  \
# 8785   1/17/2017          2016  TV-PG  2 Seasons
# 8786   9/13/2018          2016  TV-Y7  3 Seasons
# 8787  12/15/2016          2012  TV-PG   1 Season
# 8788   6/23/2018          2016   TV-Y   1 Season
# 8789    6/7/2018          2016  TV-Y7   1 Season
#
#                                               listed_in
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# ...

# %%
df.isna().any()
# Out:
# show_id         False
# type            False
# title           False
# director        False
# country         False
# date_added      False
# release_year    False
# rating          False
# duration        False
# listed_in       False
# dtype: bool

# %%
df.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
df.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
df.groupby('show_id').describe()
# Out:
#         release_year
#                count    mean std     min     25%     50%     75%     max
# show_id
# s1               1.0  2020.0 NaN  2020.0  2020.0  2020.0  2020.0  2020.0
# s10              1.0  2021.0 NaN  2021.0  2021.0  2021.0  2021.0  2021.0
# s100             1.0  2021.0 NaN  2021.0  2021.0  2021.0  2021.0  2021.0
# s1000            1.0  2021.0 NaN  2021.0  2021.0  2021.0  2021.0  2021.0
# s1001            1.0  2020.0 NaN  2020.0  2020.0  2020.0  2020.0  2020.0
# ...              ...     ...  ..     ...     ...     ...     ...     ...
# s995             1.0  2020.0 NaN  2020.0  2020.0  2020.0  2020.0  2020.0
# s996             1.0  2001.0 NaN  2001.0  2001.0  2001.0  2001.0  2001.0
# s997             1.0  2021.0 NaN  2021.0  2021.0  2021.0  2021.0  2021.0
# s998             1.0  2021.0 NaN  2021.0  2021.0  2021.0  2021.0  2021.0
# s999             1.0  2021.0 NaN  2021.0  2021.0  2021.0  2021.0  2021.0
#
# [8790 rows x 8 columns]

# %%
df['Label'] = df.type.map({'Movie':0, 'TV Show':1})
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in  Label
# 0                                      Documentaries      0
# 1  Crime TV Shows, International TV Shows, TV Act...      1
# ...

# %%
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
#Visualizations
sns.set_style("whitegrid")


plt.figure(figsize=(12, 8))
df[df.type=='Movie'].release_year.plot(bins=35, kind='hist', color='green', label='Movie Release', alpha=0.2)
                    
df[df.type=='TV Show'].release_year.plot(kind='hist', color='blue', label='Series Release', alpha=0.2)
plt.legend()
plt.xlabel("Release Year")
# Out:
# Text(0.5, 0, 'Release Year')

# %%
df[df.type=='Movie'].describe()
# Out:
#        release_year   Label
# count   6126.000000  6126.0
# mean    2013.120144     0.0
# std        9.681723     0.0
# min     1942.000000     0.0
# 25%     2012.000000     0.0
# 50%     2016.000000     0.0
# 75%     2018.000000     0.0
# max     2021.000000     0.0

# %%
df[df.type=='TV Show'].describe()
# Out:
#        release_year   Label
# count   2664.000000  2664.0
# mean    2016.627628     1.0
# std        5.735194     0.0
# min     1925.000000     1.0
# 25%     2016.000000     1.0
# 50%     2018.000000     1.0
# 75%     2020.000000     1.0
# max     2021.000000     1.0

# %%
#Countplot
import seaborn as sns

sns.countplot(x='type', data=df)
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
df[df.release_year == 2002].title.iloc[0:10]
# Out:
# 67                                            Deadly Sins
# 68      InuYasha the Movie 2: The Castle Beyond the Lo...
# 468                                   Catch Me If You Can
# 712                           Austin Powers in Goldmember
# 756                                  The Sum of All Fears
# 982                                    The Sweetest Thing
# 1116                                          The Pianist
# 1231                                 Awara Paagal Deewana
# 1603                           The Legend of Bhagat Singh
# 1647           Amandla! A Revolution in Four Part Harmony
# Name: title, dtype: object

# %%
df[df.release_year == 2021].title.iloc[0:10]
# Out:
# 1                            Ganglands
# 2                        Midnight Mass
# 3     Confessions of an Invisible Girl
# 5        The Great British Baking Show
# 6                         The Starling
# 8                         Je Suis Karl
# 12                    99 Songs (Tamil)
# 13         Bridgerton - The Afterparty
# 14       Bling Empire - The Afterparty
# 15          Cobra Kai - The Afterparty
# Name: title, dtype: object

# %%
df.title.nunique()
# Out:
# 8787

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
sns.countplot(x='country', data=df, order=df['country'].value_counts().index[:20])
plt.xticks(rotation=90)
plt.show()

# %%
#Boxplot
sns.boxplot(x='type', y='release_year', data=df)
# Out:
# <Axes: xlabel='type', ylabel='release_year'>

# %%
#Histplot
plt.hist(df['duration'].head(5), bins=20)
plt.xlabel('Duration (minutes)')
plt.ylabel('Count')
plt.show()

# %%
#Scatterplot
sns.scatterplot(x='release_year', y='duration', data=df.head(20))
# Out:
# <Axes: xlabel='release_year', ylabel='duration'>
